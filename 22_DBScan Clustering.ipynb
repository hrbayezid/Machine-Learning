# %% [markdown]
# for non linear dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN

# %%
x,y = make_moons(n_samples= 200 , noise= .1)

# %%
dict = {"data": x[:,0], "data2": x[:,1] }

df = pd.DataFrame(dict)
df
# Out:
#          data     data2
# 0   -1.035802  0.372517
# 1    0.743043  0.361023
# 2    0.900903  0.325359
# 3   -0.505350  0.894982
# 4   -0.134970  0.350103
# ..        ...       ...
# 195 -1.033646  0.264412
# 196 -0.903811  0.287705
# 197  0.217518  0.947309
# 198  0.540808  0.937479
# 199  0.897654  0.186210
#
# [200 rows x 2 columns]

# %%
sns.scatterplot(x = "data" ,y = "data2" , data=df)
# Out:
# <Axes: xlabel='data', ylabel='data2'>

# %%
db = DBSCAN(eps= .2, min_samples=5 , metric= "euclidean")

df["predict"] = db.fit_predict(x)

# %%
sns.scatterplot(x = "data" ,y = "data2" , data=df, hue = "predict")
# Out:
# <Axes: xlabel='data', ylabel='data2'>
